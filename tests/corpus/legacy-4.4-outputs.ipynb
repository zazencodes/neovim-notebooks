# %% [markdown]
# # Legacy notebook
#
# ![att](attachment:a.png)

# %%
import numpy as np
print('hello')
print('world')
# Out:
# hello
# world

# %%
6 * 7
# Out:
# 42

# %%
1/0
# Out:
# ZeroDivisionError: division by zero

# %%
plot()

# %% [raw]
# Some *raw* rst
