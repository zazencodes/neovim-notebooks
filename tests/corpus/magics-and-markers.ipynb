# %%
# %matplotlib inline
# %%time
# !ls -la
files = !ls
  # %time f()
# %time commented
x = 1 % 2
a != b

# %%
# %%bash
# echo hi

# %%
# %%
# %% id="m1"
# %% [markdown]
# # %% escaped already
%%
# %% Load data

# %% [markdown]
# %% looks like a marker once commented
# # %% also
#
# #
# plain

# %% [raw]
# # %% [raw] id="m4"
